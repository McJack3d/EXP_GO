# %%
# !pip install beautifulsoup4 lxml sentence-transformers numpy scikit-learn
# Out:
# zsh:1: command not found: pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import beautifulsoup4 as bs4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 4 import beautifulsoup4 as bs4
#
# ModuleNotFoundError: No module named 'beautifulsoup4'

# %%
fitness_data = pd.read_csv("fitness_dataset.csv")

# %%
plt.figure(figsize=(12,8))
plt.hist(fitness_data['age'], bins=62, color='blue', alpha=0.7)
plt.show()

# %%
# !pip list
# Out:
# zsh:1: command not found: pip

# %%
# Violin plot de l'âge selon le statut fit/unfit
import seaborn as sns
plt.figure(figsize=(10,6))
sns.violinplot(x='fit_status', y='age', data=fitness_data)
plt.title('Distribution de l\'âge selon le statut fit/unfit')
plt.xlabel('Statut (fit/unfit)')
plt.ylabel('Âge')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Violin plot de l'âge selon le statut fit/unfit
# ----> 2 import seaborn as sns
#       3 plt.figure(figsize=(10,6))
#       4 sns.violinplot(x='fit_status', y='age', data=fitness_data)
#
# ModuleNotFoundError: No module named 'seaborn'
